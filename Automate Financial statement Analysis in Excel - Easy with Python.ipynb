# %% [markdown]
# # Automation of Financial Statement
# $Ertiza Abbas$ <br>
# Crreated on : 22nd of June 2022

# %%
import pandas as pd 
import requests 
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
# from fmp_python.fmp import FMP

# fmp = FMP(api_key='35363aeea4cf687e0638e388d99b4071')
# fmp.get_quote('AAPL')

# %% [markdown]
# ## using financial modeling prep URL to get the data

# %%
 income_statement = pd.read_json("https://financialmodelingprep.com/api/v3/income-statement/AAPL?limit=120&apikey=35363aeea4cf687e0638e388d99b4071")

# %%
# ticker_symbols = pd.read_json("https://financialmodelingprep.com/api/v3/financial-statement-symbol-lists?apikey=35363aeea4cf687e0638e388d99b4071")

# %%
# ticker_symbols

# %% [markdown]
# ### Get the income statement data

# %%
income_statement.head()
# Out:
#         date symbol reportedCurrency     cik fillingDate         acceptedDate  \
# 0 2021-09-25   AAPL              USD  320193  2021-10-29  2021-10-28 18:04:28
# 1 2020-09-26   AAPL              USD  320193  2020-10-30  2020-10-29 18:06:25
# 2 2019-09-28   AAPL              USD  320193  2019-10-31  2019-10-30 18:12:36
# 3 2018-09-29   AAPL              USD  320193  2018-11-05  2018-11-05 08:01:40
# 4 2017-09-30   AAPL              USD  320193  2017-11-03  2017-11-03 08:01:37
#
#    calendarYear period       revenue  costOfRevenue  ...  \
# 0          2021     FY  365817000000   212981000000  ...
# 1          2020     FY  274515000000   169559000000  ...
# 2          2019     FY  260174000000   161782000000  ...
# 3          2018     FY  265595000000   163756000000  ...
# 4          2017     FY  229234000000   141048000000  ...
#
#    incomeBeforeTaxRatio  incomeTaxExpense    netIncome  netIncomeRatio  \
# 0              0.298529       14527000000  94680000000        0.258818
# ...

# %%
#set index to start from 'date'
income_statement.set_index('date', inplace= True)

# %%
income_statement.head()
# Out:
#            symbol reportedCurrency     cik fillingDate         acceptedDate  \
# date
# 2021-09-25   AAPL              USD  320193  2021-10-29  2021-10-28 18:04:28
# 2020-09-26   AAPL              USD  320193  2020-10-30  2020-10-29 18:06:25
# 2019-09-28   AAPL              USD  320193  2019-10-31  2019-10-30 18:12:36
# 2018-09-29   AAPL              USD  320193  2018-11-05  2018-11-05 08:01:40
# 2017-09-30   AAPL              USD  320193  2017-11-03  2017-11-03 08:01:37
#
#             calendarYear period       revenue  costOfRevenue   grossProfit  \
# date
# 2021-09-25          2021     FY  365817000000   212981000000  152836000000
# 2020-09-26          2020     FY  274515000000   169559000000  104956000000
# 2019-09-28          2019     FY  260174000000   161782000000   98392000000
# 2018-09-29          2018     FY  265595000000   163756000000  101839000000
# 2017-09-30          2017     FY  229234000000   141048000000   88186000000
#
# ...

# %%
income_statement.tail()
# Out:
#            symbol reportedCurrency     cik fillingDate         acceptedDate  \
# date
# 2021-09-25   AAPL              USD  320193  2021-10-29  2021-10-28 18:04:28
# 2020-09-26   AAPL              USD  320193  2020-10-30  2020-10-29 18:06:25
# 2019-09-28   AAPL              USD  320193  2019-10-31  2019-10-30 18:12:36
# 2018-09-29   AAPL              USD  320193  2018-11-05  2018-11-05 08:01:40
# 2017-09-30   AAPL              USD  320193  2017-11-03  2017-11-03 08:01:37
#
#             calendarYear period       revenue  costOfRevenue   grossProfit  \
# date
# 2021-09-25          2021     FY  365817000000   212981000000  152836000000
# 2020-09-26          2020     FY  274515000000   169559000000  104956000000
# 2019-09-28          2019     FY  260174000000   161782000000   98392000000
# 2018-09-29          2018     FY  265595000000   163756000000  101839000000
# 2017-09-30          2017     FY  229234000000   141048000000   88186000000
#
# ...

# %% [markdown]
# ### Get the 'Cash flow statement'm

# %%
cash_flow = pd.read_json("https://financialmodelingprep.com/api/v3/cash-flow-statement/AAPL?limit=120&apikey=35363aeea4cf687e0638e388d99b4071")

# %%
cash_flow.head()
# Out:
#         date symbol reportedCurrency     cik fillingDate         acceptedDate  \
# 0 2021-09-25   AAPL              USD  320193  2021-10-29  2021-10-28 18:04:28
# 1 2020-09-26   AAPL              USD  320193  2020-10-30  2020-10-29 18:06:25
# 2 2019-09-28   AAPL              USD  320193  2019-10-31  2019-10-30 18:12:36
# 3 2018-09-29   AAPL              USD  320193  2018-11-05  2018-11-05 08:01:40
# 4 2017-09-30   AAPL              USD  320193  2017-11-03  2017-11-03 08:01:37
#
#    calendarYear period    netIncome  depreciationAndAmortization  ...  \
# 0          2021     FY  94680000000                  11284000000  ...
# 1          2020     FY  57411000000                  11056000000  ...
# 2          2019     FY  55256000000                  12547000000  ...
# 3          2018     FY  59531000000                  10903000000  ...
# 4          2017     FY  48351000000                  10157000000  ...
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# ...

# %%
cash_flow.set_index('date', inplace= True)

# %%
cash_flow.head()
# Out:
#            symbol reportedCurrency     cik fillingDate         acceptedDate  \
# date
# 2021-09-25   AAPL              USD  320193  2021-10-29  2021-10-28 18:04:28
# 2020-09-26   AAPL              USD  320193  2020-10-30  2020-10-29 18:06:25
# 2019-09-28   AAPL              USD  320193  2019-10-31  2019-10-30 18:12:36
# 2018-09-29   AAPL              USD  320193  2018-11-05  2018-11-05 08:01:40
# 2017-09-30   AAPL              USD  320193  2017-11-03  2017-11-03 08:01:37
#
#             calendarYear period    netIncome  depreciationAndAmortization  \
# date
# 2021-09-25          2021     FY  94680000000                  11284000000
# 2020-09-26          2020     FY  57411000000                  11056000000
# 2019-09-28          2019     FY  55256000000                  12547000000
# 2018-09-29          2018     FY  59531000000                  10903000000
# 2017-09-30          2017     FY  48351000000                  10157000000
#
# ...

# %% [markdown]
# ### Preparing Data

# %%
income_statement.columns
# Out:
# Index(['symbol', 'reportedCurrency', 'cik', 'fillingDate', 'acceptedDate',
#        'calendarYear', 'period', 'revenue', 'costOfRevenue', 'grossProfit',
#        'grossProfitRatio', 'researchAndDevelopmentExpenses',
#        'generalAndAdministrativeExpenses', 'sellingAndMarketingExpenses',
#        'sellingGeneralAndAdministrativeExpenses', 'otherExpenses',
#        'operatingExpenses', 'costAndExpenses', 'interestIncome',
#        'interestExpense', 'depreciationAndAmortization', 'ebitda',
#        'ebitdaratio', 'operatingIncome', 'operatingIncomeRatio',
#        'totalOtherIncomeExpensesNet', 'incomeBeforeTax',
#        'incomeBeforeTaxRatio', 'incomeTaxExpense', 'netIncome',
#        'netIncomeRatio', 'eps', 'epsdiluted', 'weightedAverageShsOut',
#        'weightedAverageShsOutDil', 'link', 'finalLink'],
#       dtype='object')

# %%
data = income_statement[['revenue', 'eps']].copy()

# %% [markdown]
# **copying data to nake sure,  if i messed up things during preparation, my data and work should keep safe and okay**

# %%
data.head()
# Out:
#                  revenue     eps
# date
# 2021-09-25  365817000000  5.6700
# 2020-09-26  274515000000  3.3100
# 2019-09-28  260174000000  2.9925
# 2018-09-29  265595000000  3.0025
# 2017-09-30  229234000000  2.3175

# %% [markdown]
# * by applying above method i extract the data from main dataset columns of revenue and earning per share m

# %% [markdown]
# **get the data from "Cash flow data set and merge into one data set the "Data". <br> i need one column from cash flow and that is "freecashflow"**

# %%
cash_flow.columns
# Out:
# Index(['symbol', 'reportedCurrency', 'cik', 'fillingDate', 'acceptedDate',
#        'calendarYear', 'period', 'netIncome', 'depreciationAndAmortization',
#        'deferredIncomeTax', 'stockBasedCompensation', 'changeInWorkingCapital',
#        'accountsReceivables', 'inventory', 'accountsPayables',
#        'otherWorkingCapital', 'otherNonCashItems',
#        'netCashProvidedByOperatingActivities',
#        'investmentsInPropertyPlantAndEquipment', 'acquisitionsNet',
#        'purchasesOfInvestments', 'salesMaturitiesOfInvestments',
#        'otherInvestingActivites', 'netCashUsedForInvestingActivites',
#        'debtRepayment', 'commonStockIssued', 'commonStockRepurchased',
#        'dividendsPaid', 'otherFinancingActivites',
#        'netCashUsedProvidedByFinancingActivities',
#        'effectOfForexChangesOnCash', 'netChangeInCash', 'cashAtEndOfPeriod',
#        'cashAtBeginningOfPeriod', 'operatingCashFlow', 'capitalExpenditure',
#        'freeCashFlow', 'link', 'finalLink'],
# ...

# %%
# following is the method to cread a column in new dataset and extract and merge into one existing dataset
# i created an extra colummn given name of fcf [free cash flow]
data['fcf'] = cash_flow['freeCashFlow']

# %%
data.head()
# Out:
#                  revenue     eps          fcf
# date
# 2021-09-25  365817000000  5.6700  92953000000
# 2020-09-26  274515000000  3.3100  73365000000
# 2019-09-28  260174000000  2.9925  58896000000
# 2018-09-29  265595000000  3.0025  64121000000
# 2017-09-30  229234000000  2.3175  50803000000

# %% [markdown]
# ### Creating PERCENTAGE for required values in data

# %%
# firstly change the order in data set

data = data.sort_index()

# %%
data['rev %-chg'] = data['revenue'].pct_change()
data['eps %-chg'] = data['eps'].pct_change()
data['fcf %-chg'] = data['fcf'].pct_change()

# %%
data.head()
# Out:
#                  revenue     eps          fcf  rev %-chg  eps %-chg  fcf %-chg
# date
# 2017-09-30  229234000000  2.3175  50803000000        NaN        NaN        NaN
# 2018-09-29  265595000000  3.0025  64121000000   0.158620   0.295577   0.262150
# 2019-09-28  260174000000  2.9925  58896000000  -0.020411  -0.003331  -0.081487
# 2020-09-26  274515000000  3.3100  73365000000   0.055121   0.106099   0.245670
# 2021-09-25  365817000000  5.6700  92953000000   0.332594   0.712991   0.266994

# %% [markdown]
# ##### Right now i am interesting in only 10 years of data!! how to find it?

# %%
data_set = data.loc['2010-01-01':]   # since data only contains last 5 years enteries so i coulddn't see the previsou enteries
data_set.index = data_set.index.year

# %% [markdown]
# ### Creating seperate datasets for targeted variables
#
# *Preparing data used in each Excel sheet

# %%
# starting with revenue and so on and so forth

rev = data_set [['revenue', 'rev %-chg']].copy()
fcf = data_set [['fcf', 'fcf %-chg']].copy()
eps = data_set [['eps', 'eps %-chg']].copy()

# %%
# eps.head()
# rev.head()
fcf.head()
# Out:
#               fcf  fcf %-chg
# date
# 2017  50803000000        NaN
# 2018  64121000000   0.262150
# 2019  58896000000  -0.081487
# 2020  73365000000   0.245670
# 2021  92953000000   0.266994

# %% [markdown]
# #### Creating a function to generate excel sheet which contains similar data in each seperate sheet
# $Creating the Excel sheet$

# %%
pip install xlsxwriter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Creating the charts along with data in seperate datasheet

# %% [markdown]
# * **Following code will produce excel sheet in your working diectory along with data and sheets with charts**

# %%
def create_sheet(writer, df, sheet_name):
    df.to_excel(writer, sheet_name=sheet_name)
    worksheet = writer.sheets[sheet_name]
    workbook = writer.book
    
    chart = workbook.add_chart({'type': 'line'})
    chart.add_series({
        'name': sheet_name,
        'categories': [sheet_name, 1, 0, 5, 0],
        'values': [sheet_name, 1, 1, 5, 1],
    })

    column_chart = workbook.add_chart({'type': 'column'})
    
    column_chart.add_series({
        'name': sheet_name,
        'categories': [sheet_name, 1, 0, 5, 0],
        'values': [sheet_name, 1, 2, 5, 2],
        'y2_axis': True,
    })
    
    chart.combine(column_chart)
    chart.set_title({'name': sheet_name})
    chart.set_x_axis({'name': 'Date'})
    chart.set_y_axis({'name': 'Value'})
    column_chart.set_y2_axis({'name': '%-chg'})
    
    worksheet.insert_chart("E1", chart)

# %%
writer = pd.ExcelWriter("financials.xlsx", engine='xlsxwriter')
workbook = writer.book
create_sheet(writer, rev, 'Revenue')
create_sheet(writer, eps, 'EPS')
create_sheet(writer, fcf, 'FCF')
workbook.close()

# %% [markdown]
# ### Visualization

# %%
sns.displot(np.log(data.eps), color= 'lime', kde= False)
# Out:
# <img src="data:image/png;base64,..." width="691.2">

# %%
fig, ax= plt.subplots(2,2)
data['revenue'].plot(ax=ax[0,0], title= 'Revenue',color= 'blue')
data['eps'].plot(ax=ax[0,1], title= 'Earning per Share',color= 'lime')
data['fcf'].plot(ax=ax[1,0], title= 'fcf%-chg',color= 'navy')
data['rev %-chg'].plot(ax=ax[1,1], title= 'Change in Revene', color= 'red')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="745.6">

# %% [markdown]
# Result: runing above function will create new excel file in folder registry contaning the targeted data

# %% [markdown]
# $Thank you$
#
# **Ertiza Abbas**
